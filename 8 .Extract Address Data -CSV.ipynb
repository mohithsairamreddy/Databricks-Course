# %%
# %fs
ls 'dbfs:/Volumes/gizmobox/landing/operational_data/addresses/'

# %%
# %sql
SELECT * FROM csv.`/Volumes/gizmobox/landing/operational_data/addresses/`

# %% [markdown]
# ## Query CSV Files

# %%
# %sql
SELECT * FROM
read_files('/Volumes/gizmobox/landing/operational_data/addresses',
          format =>'csv',
          delimiter => '\t',
          header => True)

# %%
# %sql
CREATE OR REPLACE VIEW gizmobox.bronze.v_addresses AS 
SELECT * FROM
read_files('/Volumes/gizmobox/landing/operational_data/addresses',
          format =>'csv',
          delimiter => '\t',
          header => True)

# %%
# %sql
SELECT * FROM gizmobox.bronze.v_addresses
