# %% [markdown]
# # Databricks Utilities

# %% [markdown]
# ## File System Utilities

# %%
display(dbutils.fs.ls('/databricks-datasets'))

# %%
print("Folder count is :",len(dbutils.fs.ls('/databricks-datasets'))) # count folders
print("Files Count is",sum(1 for f in dbutils.fs.ls("/databricks-datasets/") if not f.isDir())) # count files

# %%
dbutils.help()

# %%
dbutils.secrets.help()

# %%
dbutils.secrets.help('list')
