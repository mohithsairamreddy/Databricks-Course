# %%
# %fs
ls 'abfss://gizmobox@gizmobox.dfs.core.windows.net/landing/external_data/payments/'

# %%
# %fs ls 'abfss://gizmobox@gizmobox.dfs.core.windows.net/landing/external_data/payments/'

# %% [markdown]
# ## CREATE EXTERNAL TABLE

# %%
# %sql

CREATE EXTERNAL TABLE gizmobox.bronze.payments
(
  payment_id STRING, 
  order_id STRING, 
  payment_timestamp STRING, 
  payment_status STRING, 
  payment_method STRING
)
USING csv
OPTIONS (
  header = 'true',
  delimiter = ','
)
LOCATION 'abfss://gizmobox@gizmobox.dfs.core.windows.net/landing/external_data/payments/';

# %%
# %sql
SELECT * FROM gizmobox.bronze.payments

# %%
# %sql DESCRIBE EXTENDED gizmobox.bronze.payments
