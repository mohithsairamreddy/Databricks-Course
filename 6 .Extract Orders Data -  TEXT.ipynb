# %%
# %fs
ls '/Volumes/gizmobox/landing/operational_data/orders/'

# %% [markdown]
# ## Query JSON Files

# %%
# %sql
SELECT *
 FROM json.`/Volumes/gizmobox/landing/operational_data/orders`

# %% [markdown]
# ## CREATE ORDERS VIEW IN BRONZE

# %%
# %sql
CREATE OR REPLACE VIEW gizmobox.bronze.v_orders AS 
SELECT *
 FROM text.`/Volumes/gizmobox/landing/operational_data/orders`

# %%
# %sql
SELECT * FROM gizmobox.bronze.v_orders
