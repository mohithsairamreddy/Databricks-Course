# %% [markdown]
# # Pyspark

# %% [markdown]
# ## Read using pyspark using sql

# %%
df = spark.sql('SELECT * FROM json.`/Volumes/gizmobox/landing/operational_data/customers/*.json`')
display(df)

# %% [markdown]
# ## Read using DataFrame API

# %%
spark.read.format('json').load('/Volumes/gizmobox/landing/operational_data/customers/*.json')

# %% [markdown]
# ## Read Table using Pyspark

# %%
read_table = spark.table('gizmobox.bronze.payments')
display(read_table)
