# %% [markdown]
# ## Query Single File

# %%
# %fs
ls '/Volumes/gizmobox/landing/operational_data/customers/'

# %%
# %sql
SELECT * FROM json.`/Volumes/gizmobox/landing/operational_data/customers/customers_2024_10.json`

# %% [markdown]
# ## Query Multiple File

# %%
# %sql
SELECT * FROM json.`/Volumes/gizmobox/landing/operational_data/customers/customers_2024_*.json`

# %% [markdown]
# ## Query All Files

# %%
# %sql
SELECT * FROM json.`/Volumes/gizmobox/landing/operational_data/customers/customers_*.json`

# %% [markdown]
# ## CREATE VIEW

# %%
# %sql
CREATE OR REPLACE VIEW gizmobox.bronze.v_customers AS 
SELECT *,
_metadata.file_path AS file_path
 FROM json.`/Volumes/gizmobox/landing/operational_data/customers/customers_*.json`

# %%
# %sql
SELECT * FROM  gizmobox.bronze.v_customers

# %% [markdown]
# ## CREATE TEMPORARY VIEW

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW tv_customers AS 
SELECT *,
_metadata.file_path AS file_path
 FROM json.`/Volumes/gizmobox/landing/operational_data/customers/customers_*.json`

# %% [markdown]
# ## CREATE GLOBAL TEMPORARY VIEW

# %%
# %sql
CREATE OR REPLACE VIEW gtv_customers AS 
SELECT *,
_metadata.file_path AS file_path
 FROM json.`/Volumes/gizmobox/landing/operational_data/customers/customers_*.json`

# %%
# %sql
SELECT * FROM gtv_customers
