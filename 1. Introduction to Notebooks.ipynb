# %% [markdown]
# # Introduction to Notebooks and Magic Comamnds
# This is a Notebook which gives notebook Introduction to Notebooks and Magic Commands

# %% [markdown]
# ## Python

# %%
print("Hello")

# %% [markdown]
# ## SQL

# %%
# %sql
SELECT * FROM system.information_schema.catalog_privileges

# %% [markdown]
# ## File System

# %%
# %fs
ls dbfs:/databricks-datasets/

# %%
# %sh

# %% [markdown]
# ## PIP

# %%
# %pip list

# %% [markdown]
# ## Shell

# %%
# %sh ps

# %% [markdown]
# ## Run or Import other Notebook

# %%
# %run "/Workspace/Users/mohithsairamreddyupskill@gmail.com/Databricks Course/Environment Variables and Functions"

# %%
schema

# %%
print(environment())
